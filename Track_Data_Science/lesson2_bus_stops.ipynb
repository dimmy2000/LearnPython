# %%
import pandas as pd

# %%
stations = pd.read_csv(open('bus_stops.csv', 'r', encoding='cp1251'),sep=';')

# %%
stations.head(10)
# Out:
#    ID                                               Name  \
# 0   1  «Дербеневская наб.», 3-й Дербеневский переулок...
# 1   2  «Наб. Тараса Шевченко», набережная Тараса Шевч...
# 2   3  «Наб. Тараса Шевченко», набережная Тараса Шевч...
# 3   4                «ВКНЦ», 3-я Черепковская улица (27)
# 4   5      «Новосущевская ул.», улица Сущёвский Вал (33)
# 5   6          «Керамический пр.», Дубнинская улица (35)
# 6   7                «Ин-т Стали», Дубнинская улица (36)
# 7   8                «Мкр. Дубки», Дубнинская улица (37)
# 8   9                «Д/к Юность», Дубнинская улица (38)
# 9  10  «Баскетбольная школа», улица 800-летия Москвы ...
#
#                        Street   OperatingOrgName  \
# 0   3-й Дербеневский переулок  ГУП «Мосгортранс»
# 1  набережная Тараса Шевченко  ГУП «Мосгортранс»
# 2  набережная Тараса Шевченко  ГУП «Мосгортранс»
# 3      3-я Черепковская улица  ГУП «Мосгортранс»
# 4         улица Сущёвский Вал  ГУП «Мосгортранс»
# 5            Дубнинская улица  ГУП «Мосгортранс»
# 6            Дубнинская улица  ГУП «Мосгортранс»
# 7            Дубнинская улица  ГУП «Мосгортранс»
# 8            Дубнинская улица  ГУП «Мосгортранс»
# 9      улица 800-летия Москвы  ГУП «Мосгортранс»
#
#                                    AdmArea                  District  \
# 0             Южный административный округ         Даниловский район
# 1          Западный административный округ        район Дорогомилово
# 2          Западный административный округ        район Дорогомилово
# 3          Западный административный округ             район Кунцево
# 4  Северо-Восточный административный округ        район Марьина Роща
# 5          Северный административный округ  район Восточное Дегунино
# 6          Северный административный округ  район Восточное Дегунино
# 7          Северный административный округ  район Восточное Дегунино
# 8          Северный административный округ  район Восточное Дегунино
# 9          Северный административный округ  район Восточное Дегунино
#
#                          RouteNumbers           StationName  Direction  \
# 0                           А632; А13     Дербеневская наб.        NaN
# 1                           А205; А91  Наб. Тараса Шевченко        NaN
# 2                                 А91  Наб. Тараса Шевченко        NaN
# 3                    А798; А816; А660                  ВКНЦ        NaN
# 4         А126; А84; А384; АТ18; АТ42     Новосущевская ул.        NaN
# 5       А799; А179; А167; А677; А677К      Керамический пр.        NaN
# 6       А799; А179; А167; А677; А677К            Ин-т Стали        NaN
# 7       А799; А179; А167; А677; А677К            Мкр. Дубки        NaN
# 8       А799; А179; А167; А677; А677К            Д/к Юность        NaN
# 9  А799; А179; А748; А167; А857; А149   Баскетбольная школа        NaN
#
#   Pavilion                                            geoData    global_id
# 0       да  Геоданные:  \nКоординаты: [\n  37.6551636,\n  ...  889076457.0
# 1       да  Геоданные:  \nКоординаты: [\n  37.57240854,\n ...  889076459.0
# 2       да  Геоданные:  \nКоординаты: [\n  37.57271647,\n ...  889076460.0
# 3       да  Геоданные:  \nКоординаты: [\n  37.37550932,\n ...  889076461.0
# 4       да  Геоданные:  \nКоординаты: [\n  37.60337594,\n ...  889076463.0
# 5       да  Геоданные:  \nКоординаты: [\n  37.55724554,\n ...  889076464.0
# 6       да  Геоданные:  \nКоординаты: [\n  37.55729147,\n ...  889076465.0
# 7       да  Геоданные:  \nКоординаты: [\n  37.55730686,\n ...  889076466.0
# 8       да  Геоданные:  \nКоординаты: [\n  37.5573643949,\...  889076467.0
# 9       да  Геоданные:  \nКоординаты: [\n  37.55636146,\n ...  889076469.0

# %%
stations_count = stations.groupby(['Street']).size()

# %%
type(stations_count)
# Out:
# pandas.core.series.Series

# %%
stations_count.sort_values(ascending=False, inplace=True)

# %%
stations_count[:5]
# Out:
# Street
# проезд без названия    627
# Варшавское шоссе       178
# Калужское шоссе        112
# шоссе Энтузиастов       79
# проспект Мира           75
# dtype: int64

# %%
pavilion_count = stations.groupby(['Pavilion']).size()
pavilion_count
# Out:
# Pavilion
# да     10158
# нет     1630
# dtype: int64
